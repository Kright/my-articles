# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
def read_file(path: str):
    lines = Path(path).read_text().split("\n")
    nums = [[float(a) for a in l.split(",")] for l in lines]

    x = np.linspace(0, 100, num = len(lines))
    y0 = [i[0] for i in nums]
    y1 = [i[1] for i in nums]
    return x, y0, y1

# %%
def show_solvers(name: str):
    fig, plots = plt.subplots(1, 3)
    for p, s in zip(plots, ["0.1", "0.01", "0.001"]):
        x, y0, y1 = read_file(f"/home/lgor/projects/2022/rotationDemo/csv/{name} {s}.csv")
        p.plot(x, y0)
        p.plot(x, y1)

# %%
def show_solver(name: str, n: int = 3):
    s = ["1.0", "0.1", "0.01", "0.001", "1.0E-4", "1.0E-5"][n]
    # x, y0, y1 = read_file(f"/home/lgor/projects/2022/gamePhysics/csv/{name} {s}.csv")
    x, y0, y1 = read_file(f"/home/lgor/projects/2022/rotationDemo/csv/{name} {s}.csv")
    plt.plot(x, y0)
    plt.plot(x, y1)

# %%
plt.rcParams['figure.figsize'] = [20, 8]

# %%
show_solver("SolverEulerNaive", n=2)

# %%
show_solver("SolverEuler2", n=2)

# %%
show_solver("SolverRK2", n=2)

# %%
show_solver("SolverRK4", n=2)

# %%
show_solver("SolverRK4", n=3)

# %%
show_solvers("SolverEulerNaive")
show_solvers("SolverEuler2")
show_solvers("SolverRK2")
show_solvers("SolverRK4")
